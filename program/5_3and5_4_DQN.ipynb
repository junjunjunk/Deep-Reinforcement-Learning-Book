# %% [markdown]
# ## 5.3、5.4  PyTorchでDQN

# %%
# パッケージのimport
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
# 動画の描画関数の宣言
# 参考URL http://nbviewer.jupyter.org/github/patrickmineault
# /xcorr-notebooks/blob/master/Render%20OpenAI%20gym%20as%20GIF.ipynb
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display


def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0),
               dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                   interval=50)

    anim.save('movie_cartpole_DQN.mp4')  # 動画のファイル名と保存です
    display(display_animation(anim, default_mode='loop'))

# %%
# 本コードでは、namedtupleを使用します。
# namedtupleを使うことで、値をフィールド名とペアで格納できます。
# すると値に対して、フィールド名でアクセスできて便利です。
# https://docs.python.jp/3/library/collections.html#collections.namedtuple
# 以下は使用例です

from collections import namedtuple

# 各ステップでのtransition(経験)をnamedtupleで変換
Tr = namedtuple('tr', ('name_a', 'value_b'))
Tr_object = Tr('名前Aです', 100)

print(Tr_object)  # 出力：tr(name_a='名前Aです', value_b=100)
print(Tr_object.value_b)  # 出力：100
# Out:
# tr(name_a='名前Aです', value_b=100)
# 100

# %%
# namedtupleを生成
from collections import namedtuple

Transition = namedtuple(
    'Transition', ('state', 'action', 'next_state', 'reward'))

# %%
# 定数の設定
ENV = 'CartPole-v0'  # 使用する課題名
GAMMA = 0.99  # 時間割引率
MAX_STEPS = 200  # 1試行のstep数
NUM_EPISODES = 500  # 最大試行回数

# %%
# 経験を保存するメモリクラスを定義します


class ReplayMemory:

    def __init__(self, CAPACITY):
        self.capacity = CAPACITY  # メモリの最大長さ
        self.memory = []  # 経験を保存する変数
        self.index = 0  # 保存するindexを示す変数

    def push(self, state, action, state_next, reward):
        '''transition = (state, action, state_next, reward)をメモリに保存する'''

        if len(self.memory) < self.capacity:
            self.memory.append(None)  # メモリが満タンでないときは足す

        # namedtupleのTransitionを使用し、値とフィールド名をペアにして保存します
        self.memory[self.index] = Transition(state, action, state_next, reward)

        self.index = (self.index + 1) % self.capacity  # 保存するindexを1つずらす
        #　メモリがいっぱいになったら古い内容から上書き

    def sample(self, batch_size):
        '''batch_size分だけ、ランダムに保存内容を取り出す'''
        return random.sample(self.memory, batch_size)

    def __len__(self):
        '''関数lenに対して、現在の変数memoryの長さを返す'''
        return len(self.memory)

# %%
# エージェントが持つ脳となるクラスです、DQNを実行します、DQNの中心部　
# Q関数をディープラーニングのネットワークをクラスとして定義

import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

BATCH_SIZE = 32
CAPACITY = 10000


class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # CartPoleの行動（右に左に押す）の2を取得

        # 経験を記憶するメモリオブジェクトを生成
        self.memory = ReplayMemory(CAPACITY)

        # ニューラルネットワークを構築
        self.model = nn.Sequential()
        self.model.add_module('fc1', nn.Linear(num_states, 32))
        self.model.add_module('relu1', nn.ReLU())
        self.model.add_module('fc2', nn.Linear(32, 32))
        self.model.add_module('relu2', nn.ReLU())
        self.model.add_module('fc3', nn.Linear(32, num_actions))

        print(self.model)  # ネットワークの形を出力

        # 最適化手法の設定
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.0001)

    def replay(self):
        '''Experience Replayでネットワークの結合パラメータを学習'''

        # -----------------------------------------
        # 1. メモリサイズの確認
        # -----------------------------------------
        # 1.1 メモリサイズがミニバッチより小さい場合は終了
        if len(self.memory) < BATCH_SIZE:
            return

        # -----------------------------------------
        # 2. ミニバッチの作成
        # -----------------------------------------
        # 2.1 メモリからミニバッチ分のデータを取り出す
        transitions = self.memory.sample(BATCH_SIZE)

        # 2.2 各変数をミニバッチに対応する形に変形
        # transitionsは1stepごとの(state, action, state_next, reward)が、BATCH_SIZE分格納されている
        # つまり、(state, action, state_next, reward)×BATCH_SIZE
        # これをミニバッチにしたい。つまり
        # (state×BATCH_SIZE, action×BATCH_SIZE, state_next×BATCH_SIZE, reward×BATCH_SIZE)にする
        batch = Transition(*zip(*transitions))

        # 2.3 各変数の要素をミニバッチに対応する形に変形し、ネットワークで扱えるようVariableにする
        # 例えばstateの場合、[torch.FloatTensor of size 1x4]がBATCH_SIZE分並んでいるのですが、
        # それを torch.FloatTensor of size BATCH_SIZEx4 に変換します
        # 状態、行動、報酬、non_finalの状態のミニバッチのVariableを作成
        # catはConcatenates（結合）のことです。
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state
                                           if s is not None])
        # 次の状態があるかでQ学習の更新式も変わる
        # non_final_next_states = 次の状態が存在する状態だけを集めたミニバッチ

        # -----------------------------------------
        # 3. 教師信号となるQ(s_t, a_t)値を求める
        # -----------------------------------------
        # 教師信号＝ネットワークが本来出力して欲しい値
        # 3.1 Q値を求めるためにネットワークを推論モードに切り替える
        self.model.eval()

        # 3.2 ネットワークが出力したQ(s_t, a_t)を求める
        # self.model(state_batch)は、右左の両方のQ値を出力しており
        # [torch.FloatTensor of size BATCH_SIZEx2]になっている。
        # ここから実行したアクションa_tに対応するQ値を求めるため、action_batchで行った行動a_tが右か左かのindexを求め
        # それに対応するQ値をgatherでひっぱり出す。
        state_action_values = self.model(state_batch).gather(1, action_batch)
        # 実際にNNが出力したQ(s_t,a_t)
        
        # 3.3 max{Q(s_t+1, a)}値を求める。ただし次の状態があるかに注意。

        # cartpoleがdoneになっておらず、next_stateがあるかをチェックするインデックスマスクを作成
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None,
                                                    batch.next_state)))
        non_final_mask = non_final_mask.type(torch.bool)
        #torchバージョン問題で型変換
        
        # まずは全部0にしておく
        next_state_values = torch.zeros(BATCH_SIZE)

        # 次の状態があるindexの最大Q値を求める
        # 出力にアクセスし、max(1)で列方向の最大値の[値、index]を求めます
        # そしてそのQ値（index=0）を出力します
        # detachでその値を取り出します
        # 次の状態が存在しない場合は０
        next_state_values[non_final_mask] = self.model(
            non_final_next_states).max(1)[0].detach()
        # detach() 値を取り出す、その変数が保持しているそれまでの計算履歴を失いbpする際に微分計算しなくなる。
        # 教師信号は固定されたものである必要があるので微分操作が行われないようにする
        # 予測として出力したQ(s_t,a_t)はdetachしない
        
        # 3.4 教師となるQ(s_t, a_t)値を、Q学習の式から求める
        expected_state_action_values = reward_batch + GAMMA * next_state_values

        # -----------------------------------------
        # 4. 結合パラメータの更新
        # -----------------------------------------
        # 4.1 ネットワークを訓練モードに切り替える
        self.model.train()

        # 4.2 損失関数を計算する（smooth_l1_loss=Huberloss）
        # expected_state_action_valuesは
        # sizeが[minbatch]になっているので、unsqueezeで[minibatch x 1]へ
        loss = F.smooth_l1_loss(state_action_values,
                                expected_state_action_values.unsqueeze(1))

        # 4.3 結合パラメータを更新する
        self.optimizer.zero_grad()  # 勾配をリセット
        loss.backward()  # バックプロパゲーションを計算
        self.optimizer.step()  # 結合パラメータを更新

    def decide_action(self, state, episode):
        '''現在の状態に応じて、行動を決定する'''
        # ε-greedy法で徐々に最適行動のみを採用する
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            self.model.eval()  # ネットワークを推論モードに切り替える
            with torch.no_grad():
                action = self.model(state).max(1)[1].view(1, 1)
            # ネットワークの出力の最大値のindexを取り出します = max(1)[1]
            # .view(1,1)は[torch.LongTensor of size 1]　を size 1x1 に変換します

        else:
            # 0,1の行動をランダムに返す
            action = torch.LongTensor(
                [[random.randrange(self.num_actions)]])  # 0,1の行動をランダムに返す
            # actionは[torch.LongTensor of size 1x1]の形になります

        return action

# %%
# CartPoleで動くエージェントクラスです、棒付き台車そのものになります


class Agent:
    def __init__(self, num_states, num_actions):
        '''課題の状態と行動の数を設定する'''
        self.brain = Brain(num_states, num_actions)  # エージェントが行動を決定するための頭脳を生成

    def update_q_function(self):
        '''Q関数を更新する'''
        self.brain.replay()

    def get_action(self, state, episode):
        '''行動を決定する'''
        action = self.brain.decide_action(state, episode)
        return action

    def memorize(self, state, action, state_next, reward):
        '''memoryオブジェクトに、state, action, state_next, rewardの内容を保存する'''
        # 経験したデータ(trainsition)を格納
        self.brain.memory.push(state, action, state_next, reward)

# %%
# CartPoleを実行する環境のクラスです


class Environment:

    def __init__(self):
        self.env = gym.make(ENV)  # 実行する課題を設定
        num_states = self.env.observation_space.shape[0]  # 課題の状態数4を取得
        num_actions = self.env.action_space.n  # CartPoleの行動（右に左に押す）の2を取得
        self.agent = Agent(num_states, num_actions)  # 環境内で行動するAgentを生成

        
    def run(self):
        '''実行'''
        episode_10_list = np.zeros(10)  # 10試行分の立ち続けたstep数を格納し、平均ステップ数を出力に利用
        complete_episodes = 0  # 195step以上連続で立ち続けた試行数
        episode_final = False  # 最後の試行フラグ
        frames = []  # 最後の試行を動画にするために画像を格納する変数

        for episode in range(NUM_EPISODES):  # 最大試行数分繰り返す
            observation = self.env.reset()  # 環境の初期化

            state = observation  # 観測をそのまま状態sとして使用
            state = torch.from_numpy(state).type(
                torch.FloatTensor)  # NumPy変数をPyTorchのテンソルに変換
            state = torch.unsqueeze(state, 0)  # size 4をsize 1x4に変換

            for step in range(MAX_STEPS):  # 1エピソードのループ

                if episode_final is True:  # 最終試行ではframesに各時刻の画像を追加していく
                    frames.append(self.env.render(mode='rgb_array'))

                action = self.agent.get_action(state, episode)  # 行動を求める

                # 行動a_tの実行により、s_{t+1}とdoneフラグを求める
                # actionから.item()を指定して、中身を取り出す
                observation_next, _, done, _ = self.env.step(
                    action.item())  # rewardとinfoは使わないので_にする

                # 報酬を与える。さらにepisodeの終了評価と、state_nextを設定する
                if done:  # ステップ数が200経過するか、一定角度以上傾くとdoneはtrueになる
                    state_next = None  # 次の状態はないので、Noneを格納

                    # 直近10episodeの立てたstep数リストに追加
                    episode_10_list = np.hstack(
                        (episode_10_list[1:], step + 1))

                    if step < 195:
                        reward = torch.FloatTensor(
                            [-1.0])  # 途中でこけたら罰則として報酬-1を与える
                        complete_episodes = 0  # 連続成功記録をリセット
                    else:
                        reward = torch.FloatTensor([1.0])  # 立ったまま終了時は報酬1を与える
                        complete_episodes = complete_episodes + 1  # 連続記録を更新
                else:
                    reward = torch.FloatTensor([0.0])  # 普段は報酬0
                    state_next = observation_next  # 観測をそのまま状態とする
                    state_next = torch.from_numpy(state_next).type(
                        torch.FloatTensor)  # numpy変数をPyTorchのテンソルに変換
                    state_next = torch.unsqueeze(state_next, 0)  # size 4をsize 1x4に変換

                # メモリに経験を追加
                self.agent.memorize(state, action, state_next, reward)

                # Experience ReplayでQ関数を更新する
                self.agent.update_q_function()

                # 観測の更新
                state = state_next

                # 終了時の処理
                if done:
                    print('%d Episode: Finished after %d steps：10試行の平均step数 = %.1lf' % (
                        episode, step + 1, episode_10_list.mean()))
                    break

            if episode_final is True:
                # 動画を保存と描画
                display_frames_as_gif(frames)
                break

            # 10連続で200step経ち続けたら成功
            if complete_episodes >= 10:
                print('10回連続成功')
                episode_final = True  # 次の試行を描画を行う最終試行とする

# %%
# main クラス
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Sequential(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode: Finished after 16 steps：10試行の平均step数 = 1.6
# 1 Episode: Finished after 13 steps：10試行の平均step数 = 2.9
# 2 Episode: Finished after 11 steps：10試行の平均step数 = 4.0
# 3 Episode: Finished after 9 steps：10試行の平均step数 = 4.9
# 4 Episode: Finished after 8 steps：10試行の平均step数 = 5.7
# 5 Episode: Finished after 10 steps：10試行の平均step数 = 6.7
# 6 Episode: Finished after 9 steps：10試行の平均step数 = 7.6
# 7 Episode: Finished after 11 steps：10試行の平均step数 = 8.7
# 8 Episode: Finished after 9 steps：10試行の平均step数 = 9.6
# 9 Episode: Finished after 10 steps：10試行の平均step数 = 10.6
# 10 Episode: Finished after 9 steps：10試行の平均step数 = 9.9
# 11 Episode: Finished after 9 steps：10試行の平均step数 = 9.5
# 12 Episode: Finished after 10 steps：10試行の平均step数 = 9.4
# 13 Episode: Finished after 10 steps：10試行の平均step数 = 9.5
# 14 Episode: Finished after 10 steps：10試行の平均step数 = 9.7
# 15 Episode: Finished after 8 steps：10試行の平均step数 = 9.5
# 16 Episode: Finished after 9 steps：10試行の平均step数 = 9.5
# 17 Episode: Finished after 9 steps：10試行の平均step数 = 9.3
# 18 Episode: Finished after 9 steps：10試行の平均step数 = 9.3
# 19 Episode: Finished after 9 steps：10試行の平均step数 = 9.2
# 20 Episode: Finished after 9 steps：10試行の平均step数 = 9.2
# 21 Episode: Finished after 10 steps：10試行の平均step数 = 9.3
# 22 Episode: Finished after 9 steps：10試行の平均step数 = 9.2
# 23 Episode: Finished after 9 steps：10試行の平均step数 = 9.1
# 24 Episode: Finished after 11 steps：10試行の平均step数 = 9.2
# 25 Episode: Finished after 12 steps：10試行の平均step数 = 9.6
# 26 Episode: Finished after 9 steps：10試行の平均step数 = 9.6
# 27 Episode: Finished after 29 steps：10試行の平均step数 = 11.6
# 28 Episode: Finished after 54 steps：10試行の平均step数 = 16.1
# 29 Episode: Finished after 27 steps：10試行の平均step数 = 17.9
# 30 Episode: Finished after 25 steps：10試行の平均step数 = 19.5
# 31 Episode: Finished after 10 steps：10試行の平均step数 = 19.5
# 32 Episode: Finished after 9 steps：10試行の平均step数 = 19.5
# 33 Episode: Finished after 9 steps：10試行の平均step数 = 19.5
# 34 Episode: Finished after 11 steps：10試行の平均step数 = 19.5
# 35 Episode: Finished after 10 steps：10試行の平均step数 = 19.3
# 36 Episode: Finished after 9 steps：10試行の平均step数 = 19.3
# 37 Episode: Finished after 9 steps：10試行の平均step数 = 17.3
# 38 Episode: Finished after 19 steps：10試行の平均step数 = 13.8
# 39 Episode: Finished after 71 steps：10試行の平均step数 = 18.2
# 40 Episode: Finished after 48 steps：10試行の平均step数 = 20.5
# 41 Episode: Finished after 18 steps：10試行の平均step数 = 21.3
# 42 Episode: Finished after 22 steps：10試行の平均step数 = 22.6
# 43 Episode: Finished after 16 steps：10試行の平均step数 = 23.3
# 44 Episode: Finished after 16 steps：10試行の平均step数 = 23.8
# 45 Episode: Finished after 20 steps：10試行の平均step数 = 24.8
# 46 Episode: Finished after 14 steps：10試行の平均step数 = 25.3
# 47 Episode: Finished after 25 steps：10試行の平均step数 = 26.9
# 48 Episode: Finished after 34 steps：10試行の平均step数 = 28.4
# 49 Episode: Finished after 25 steps：10試行の平均step数 = 23.8
# 50 Episode: Finished after 26 steps：10試行の平均step数 = 21.6
# 51 Episode: Finished after 35 steps：10試行の平均step数 = 23.3
# 52 Episode: Finished after 15 steps：10試行の平均step数 = 22.6
# 53 Episode: Finished after 23 steps：10試行の平均step数 = 23.3
# 54 Episode: Finished after 20 steps：10試行の平均step数 = 23.7
# 55 Episode: Finished after 59 steps：10試行の平均step数 = 27.6
# 56 Episode: Finished after 56 steps：10試行の平均step数 = 31.8
# 57 Episode: Finished after 32 steps：10試行の平均step数 = 32.5
# 58 Episode: Finished after 77 steps：10試行の平均step数 = 36.8
# 59 Episode: Finished after 36 steps：10試行の平均step数 = 37.9
# 60 Episode: Finished after 24 steps：10試行の平均step数 = 37.7
# 61 Episode: Finished after 41 steps：10試行の平均step数 = 38.3
# 62 Episode: Finished after 65 steps：10試行の平均step数 = 43.3
# 63 Episode: Finished after 29 steps：10試行の平均step数 = 43.9
# 64 Episode: Finished after 31 steps：10試行の平均step数 = 45.0
# 65 Episode: Finished after 39 steps：10試行の平均step数 = 43.0
# 66 Episode: Finished after 24 steps：10試行の平均step数 = 39.8
# 67 Episode: Finished after 27 steps：10試行の平均step数 = 39.3
# 68 Episode: Finished after 36 steps：10試行の平均step数 = 35.2
# 69 Episode: Finished after 49 steps：10試行の平均step数 = 36.5
# 70 Episode: Finished after 23 steps：10試行の平均step数 = 36.4
# 71 Episode: Finished after 25 steps：10試行の平均step数 = 34.8
# 72 Episode: Finished after 101 steps：10試行の平均step数 = 38.4
# 73 Episode: Finished after 27 steps：10試行の平均step数 = 38.2
# 74 Episode: Finished after 30 steps：10試行の平均step数 = 38.1
# 75 Episode: Finished after 35 steps：10試行の平均step数 = 37.7
# 76 Episode: Finished after 39 steps：10試行の平均step数 = 39.2
# 77 Episode: Finished after 41 steps：10試行の平均step数 = 40.6
# 78 Episode: Finished after 80 steps：10試行の平均step数 = 45.0
# 79 Episode: Finished after 29 steps：10試行の平均step数 = 43.0
# 80 Episode: Finished after 49 steps：10試行の平均step数 = 45.6
# 81 Episode: Finished after 52 steps：10試行の平均step数 = 48.3
# 82 Episode: Finished after 63 steps：10試行の平均step数 = 44.5
# 83 Episode: Finished after 35 steps：10試行の平均step数 = 45.3
# 84 Episode: Finished after 67 steps：10試行の平均step数 = 49.0
# 85 Episode: Finished after 110 steps：10試行の平均step数 = 56.5
# 86 Episode: Finished after 73 steps：10試行の平均step数 = 59.9
# 87 Episode: Finished after 200 steps：10試行の平均step数 = 75.8
# 88 Episode: Finished after 42 steps：10試行の平均step数 = 72.0
# 89 Episode: Finished after 66 steps：10試行の平均step数 = 75.7
# 90 Episode: Finished after 41 steps：10試行の平均step数 = 74.9
# 91 Episode: Finished after 33 steps：10試行の平均step数 = 73.0
# 92 Episode: Finished after 36 steps：10試行の平均step数 = 70.3
# 93 Episode: Finished after 40 steps：10試行の平均step数 = 70.8
# 94 Episode: Finished after 37 steps：10試行の平均step数 = 67.8
# 95 Episode: Finished after 147 steps：10試行の平均step数 = 71.5
# 96 Episode: Finished after 81 steps：10試行の平均step数 = 72.3
# 97 Episode: Finished after 132 steps：10試行の平均step数 = 65.5
# 98 Episode: Finished after 64 steps：10試行の平均step数 = 67.7
# 99 Episode: Finished after 64 steps：10試行の平均step数 = 67.5
# 100 Episode: Finished after 63 steps：10試行の平均step数 = 69.7
# 101 Episode: Finished after 46 steps：10試行の平均step数 = 71.0
# 102 Episode: Finished after 90 steps：10試行の平均step数 = 76.4
# 103 Episode: Finished after 64 steps：10試行の平均step数 = 78.8
# 104 Episode: Finished after 68 steps：10試行の平均step数 = 81.9
# 105 Episode: Finished after 85 steps：10試行の平均step数 = 75.7
# 106 Episode: Finished after 47 steps：10試行の平均step数 = 72.3
# 107 Episode: Finished after 63 steps：10試行の平均step数 = 65.4
# 108 Episode: Finished after 76 steps：10試行の平均step数 = 66.6
# 109 Episode: Finished after 55 steps：10試行の平均step数 = 65.7
# 110 Episode: Finished after 75 steps：10試行の平均step数 = 66.9
# 111 Episode: Finished after 55 steps：10試行の平均step数 = 67.8
# 112 Episode: Finished after 87 steps：10試行の平均step数 = 67.5
# 113 Episode: Finished after 49 steps：10試行の平均step数 = 66.0
# 114 Episode: Finished after 60 steps：10試行の平均step数 = 65.2
# 115 Episode: Finished after 78 steps：10試行の平均step数 = 64.5
# 116 Episode: Finished after 94 steps：10試行の平均step数 = 69.2
# 117 Episode: Finished after 81 steps：10試行の平均step数 = 71.0
# 118 Episode: Finished after 58 steps：10試行の平均step数 = 69.2
# 119 Episode: Finished after 52 steps：10試行の平均step数 = 68.9
# 120 Episode: Finished after 152 steps：10試行の平均step数 = 76.6
# 121 Episode: Finished after 66 steps：10試行の平均step数 = 77.7
# 122 Episode: Finished after 90 steps：10試行の平均step数 = 78.0
# 123 Episode: Finished after 85 steps：10試行の平均step数 = 81.6
# 124 Episode: Finished after 77 steps：10試行の平均step数 = 83.3
# 125 Episode: Finished after 81 steps：10試行の平均step数 = 83.6
# 126 Episode: Finished after 86 steps：10試行の平均step数 = 82.8
# 127 Episode: Finished after 82 steps：10試行の平均step数 = 82.9
# 128 Episode: Finished after 78 steps：10試行の平均step数 = 84.9
# 129 Episode: Finished after 97 steps：10試行の平均step数 = 89.4
# 130 Episode: Finished after 74 steps：10試行の平均step数 = 81.6
# 131 Episode: Finished after 94 steps：10試行の平均step数 = 84.4
# 132 Episode: Finished after 67 steps：10試行の平均step数 = 82.1
# 133 Episode: Finished after 76 steps：10試行の平均step数 = 81.2
# 134 Episode: Finished after 169 steps：10試行の平均step数 = 90.4
# 135 Episode: Finished after 66 steps：10試行の平均step数 = 88.9
# 136 Episode: Finished after 70 steps：10試行の平均step数 = 87.3
# 137 Episode: Finished after 117 steps：10試行の平均step数 = 90.8
# 138 Episode: Finished after 72 steps：10試行の平均step数 = 90.2
# 139 Episode: Finished after 73 steps：10試行の平均step数 = 87.8
# 140 Episode: Finished after 62 steps：10試行の平均step数 = 86.6
# 141 Episode: Finished after 161 steps：10試行の平均step数 = 93.3
# 142 Episode: Finished after 84 steps：10試行の平均step数 = 95.0
# 143 Episode: Finished after 64 steps：10試行の平均step数 = 93.8
# 144 Episode: Finished after 76 steps：10試行の平均step数 = 84.5
# 145 Episode: Finished after 71 steps：10試行の平均step数 = 85.0
# 146 Episode: Finished after 74 steps：10試行の平均step数 = 85.4
# 147 Episode: Finished after 76 steps：10試行の平均step数 = 81.3
# 148 Episode: Finished after 140 steps：10試行の平均step数 = 88.1
# 149 Episode: Finished after 70 steps：10試行の平均step数 = 87.8
# 150 Episode: Finished after 62 steps：10試行の平均step数 = 87.8
# 151 Episode: Finished after 71 steps：10試行の平均step数 = 78.8
# 152 Episode: Finished after 76 steps：10試行の平均step数 = 78.0
# 153 Episode: Finished after 54 steps：10試行の平均step数 = 77.0
# 154 Episode: Finished after 58 steps：10試行の平均step数 = 75.2
# 155 Episode: Finished after 75 steps：10試行の平均step数 = 75.6
# 156 Episode: Finished after 109 steps：10試行の平均step数 = 79.1
# 157 Episode: Finished after 58 steps：10試行の平均step数 = 77.3
# 158 Episode: Finished after 66 steps：10試行の平均step数 = 69.9
# 159 Episode: Finished after 64 steps：10試行の平均step数 = 69.3
# 160 Episode: Finished after 80 steps：10試行の平均step数 = 71.1
# 161 Episode: Finished after 66 steps：10試行の平均step数 = 70.6
# 162 Episode: Finished after 74 steps：10試行の平均step数 = 70.4
# 163 Episode: Finished after 65 steps：10試行の平均step数 = 71.5
# 164 Episode: Finished after 79 steps：10試行の平均step数 = 73.6
# 165 Episode: Finished after 62 steps：10試行の平均step数 = 72.3
# 166 Episode: Finished after 72 steps：10試行の平均step数 = 68.6
# 167 Episode: Finished after 77 steps：10試行の平均step数 = 70.5
# 168 Episode: Finished after 117 steps：10試行の平均step数 = 75.6
# 169 Episode: Finished after 90 steps：10試行の平均step数 = 78.2
# 170 Episode: Finished after 65 steps：10試行の平均step数 = 76.7
# 171 Episode: Finished after 107 steps：10試行の平均step数 = 80.8
# 172 Episode: Finished after 105 steps：10試行の平均step数 = 83.9
# 173 Episode: Finished after 60 steps：10試行の平均step数 = 83.4
# 174 Episode: Finished after 106 steps：10試行の平均step数 = 86.1
# 175 Episode: Finished after 109 steps：10試行の平均step数 = 90.8
# 176 Episode: Finished after 100 steps：10試行の平均step数 = 93.6
# 177 Episode: Finished after 87 steps：10試行の平均step数 = 94.6
# 178 Episode: Finished after 74 steps：10試行の平均step数 = 90.3
# 179 Episode: Finished after 82 steps：10試行の平均step数 = 89.5
# 180 Episode: Finished after 83 steps：10試行の平均step数 = 91.3
# 181 Episode: Finished after 111 steps：10試行の平均step数 = 91.7
# 182 Episode: Finished after 100 steps：10試行の平均step数 = 91.2
# 183 Episode: Finished after 100 steps：10試行の平均step数 = 95.2
# 184 Episode: Finished after 120 steps：10試行の平均step数 = 96.6
# 185 Episode: Finished after 197 steps：10試行の平均step数 = 105.4
# 186 Episode: Finished after 200 steps：10試行の平均step数 = 115.4
# 187 Episode: Finished after 200 steps：10試行の平均step数 = 126.7
# 188 Episode: Finished after 200 steps：10試行の平均step数 = 139.3
# 189 Episode: Finished after 200 steps：10試行の平均step数 = 151.1
# 190 Episode: Finished after 200 steps：10試行の平均step数 = 162.8
# 191 Episode: Finished after 200 steps：10試行の平均step数 = 171.7
# 192 Episode: Finished after 200 steps：10試行の平均step数 = 181.7
# 193 Episode: Finished after 169 steps：10試行の平均step数 = 188.6
# 194 Episode: Finished after 200 steps：10試行の平均step数 = 196.6
# 195 Episode: Finished after 200 steps：10試行の平均step数 = 196.9
# 196 Episode: Finished after 200 steps：10試行の平均step数 = 196.9
# 197 Episode: Finished after 172 steps：10試行の平均step数 = 194.1
# 198 Episode: Finished after 200 steps：10試行の平均step数 = 194.1
# 199 Episode: Finished after 200 steps：10試行の平均step数 = 194.1
# 200 Episode: Finished after 200 steps：10試行の平均step数 = 194.1
# 201 Episode: Finished after 200 steps：10試行の平均step数 = 194.1
# 202 Episode: Finished after 200 steps：10試行の平均step数 = 194.1
# 203 Episode: Finished after 165 steps：10試行の平均step数 = 193.7
# 204 Episode: Finished after 200 steps：10試行の平均step数 = 193.7
# 205 Episode: Finished after 200 steps：10試行の平均step数 = 193.7
# 206 Episode: Finished after 137 steps：10試行の平均step数 = 187.4
# 207 Episode: Finished after 200 steps：10試行の平均step数 = 190.2
# 208 Episode: Finished after 167 steps：10試行の平均step数 = 186.9
# 209 Episode: Finished after 171 steps：10試行の平均step数 = 184.0
# 210 Episode: Finished after 158 steps：10試行の平均step数 = 179.8
# 211 Episode: Finished after 176 steps：10試行の平均step数 = 177.4
# 212 Episode: Finished after 181 steps：10試行の平均step数 = 175.5
# 213 Episode: Finished after 168 steps：10試行の平均step数 = 175.8
# 214 Episode: Finished after 200 steps：10試行の平均step数 = 175.8
# 215 Episode: Finished after 200 steps：10試行の平均step数 = 175.8
# 216 Episode: Finished after 200 steps：10試行の平均step数 = 182.1
# 217 Episode: Finished after 200 steps：10試行の平均step数 = 182.1
# 218 Episode: Finished after 200 steps：10試行の平均step数 = 185.4
# 219 Episode: Finished after 200 steps：10試行の平均step数 = 188.3
# 220 Episode: Finished after 200 steps：10試行の平均step数 = 192.5
# 221 Episode: Finished after 200 steps：10試行の平均step数 = 194.9
# 222 Episode: Finished after 200 steps：10試行の平均step数 = 196.8
# 223 Episode: Finished after 200 steps：10試行の平均step数 = 200.0
# 10回連続成功
# 224 Episode: Finished after 200 steps：10試行の平均step数 = 200.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgPUINTAYHDYMWNHDB">
#     <br>
#     <input id="_anim_sliderPUINTAYHDYMWNHDB" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animPUINTAYHDYMWNHDB.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animPUINTAYHDYMWNHDB.slower()">&#8211;</button>
#     <button onclick="animPUINTAYHDYMWNHDB.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animPUINTAYHDYMWNHDB.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animPUINTAYHDYMWNHDB.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animPUINTAYHDYMWNHDB.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animPUINTAYHDYMWNHDB.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animPUINTAYHDYMWNHDB.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animPUINTAYHDYMWNHDB.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animPUINTAYHDYMWNHDB.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectPUINTAYHDYMWNHDB" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgPUINTAYHDYMWNHDB";
#     var slider_id = "_anim_sliderPUINTAYHDYMWNHDB";
#     var loop_select_id = "_anim_loop_selectPUINTAYHDYMWNHDB";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6
